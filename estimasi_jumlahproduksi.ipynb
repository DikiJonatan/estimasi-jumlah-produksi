# %%
Penjelasan crisp dm

# %%
1. Bussiness Understanding

Setiap perusahaan pasti mempunyai hasil produksi yang mereka olah, dataset ini berisi 
parameter yang bisa mempengaruhi jumlah produksi, biasanya yang dilakukan perusahaan menghitung manual
dan terkadang memberikan hasil yang kurang optimal.

Untuk itu prediksi ini dibuat untuk memprediksi jumlah produksi 

Dataset ini didapat dari kaggle "https://www.kaggle.com/datasets/febymelania/data-regresi-linier?select=data.xlsx"

2. Data understanding
Fitur yang mempngaruhi dalam dataset untuk mencari hasil jumlah produksi ini adalah
Luas_Lahan,Jumlah_Pohon,Pupuk_Kandang,Pupuk_Phonska,Pestisida,Tenaga_Kerja

Tipe data yang hanya boleh digunkana adalan int dan float
 0   Responden        60 non-null     int64
 1   Jumlah_Produksi  60 non-null     int64
 2   Luas_Lahan       60 non-null     int64
 3   Jumlah_Pohon     60 non-null     int64
 4   Pupuk_Kandang    60 non-null     int64
 5   Pupuk_Phonska    60 non-null     int64
 6   Pestisida        60 non-null     int64
 7   Tenaga_Kerja     60 non-null     int64

Data int berisi 8

3. Data preparation
tahap ini melakukan seleksi fitur, fitur apa saja yang dibutuhkan
x : Luas_Lahan,Jumlah_Pohon,Pupuk_Kandang,Pupuk_Phonska,Pestisida,Tenaga_Kerja
y : Jumlah_Produksi

4. Modelling
Karena pada tahap selseksi hanya tipe data integer dan float, maka model yg cocok adalah
regression linear

5. Evaluasi
Tahap setelah modelling yaitu evaluasi, tahap ini diprediksi apakah model yang dipakai benar
Dan di uji tingkat akurasi supaya lebih percaya

6. Deployment
Tahap terakhir dalam crisp dm adalah deployment, di deploy ke dalam streamlit
maka analisis ini selesai

# %% [markdown]
# # deskripsi library yang digunakan

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # Memanggil Dataset

# %%
df = pd.read_csv('data.csv')

# %% [markdown]
# # Deskripsi Dataset

# %%
df.head()
# Out:
#    Responden  Jumlah_Produksi  Luas_Lahan  Jumlah_Pohon  Pupuk_Kandang  \
# 0          1              200         900            20             50
# 1          2              500         500            50            250
# 2          3              500         500            50            250
# 3          4              900         900            60            450
# 4          5              900         900            60            450
#
#    Pupuk_Phonska  Pestisida  Tenaga_Kerja
# 0             10        600            27
# 1             25       1600            21
# 2             25       1600            33
# 3             45       3600            40
# 4             45       3600            50

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 60 entries, 0 to 59
# Data columns (total 8 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Responden        60 non-null     int64
#  1   Jumlah_Produksi  60 non-null     int64
#  2   Luas_Lahan       60 non-null     int64
#  3   Jumlah_Pohon     60 non-null     int64
#  4   Pupuk_Kandang    60 non-null     int64
#  5   Pupuk_Phonska    60 non-null     int64
#  6   Pestisida        60 non-null     int64
#  7   Tenaga_Kerja     60 non-null     int64
# dtypes: int64(8)
# memory usage: 3.9 KB

# %%
sns.heatmap(df.isnull())
# Out:
# <Axes: >

# %%
df.describe()
# Out:
#        Responden  Jumlah_Produksi   Luas_Lahan  Jumlah_Pohon  Pupuk_Kandang  \
# count  60.000000        60.000000    60.000000     60.000000      60.000000
# mean   30.500000       404.166667   807.000000     37.833333     199.250000
# std    17.464249       215.361672   595.634685     16.425659     109.601841
# min     1.000000       150.000000   250.000000     20.000000      50.000000
# 25%    15.750000       200.000000   492.500000     20.000000     100.000000
# 50%    30.500000       325.000000   600.000000     30.000000     150.000000
# 75%    45.250000       500.000000   900.000000     50.000000     250.000000
# max    60.000000       900.000000  2800.000000     80.000000     450.000000
#
#        Pupuk_Phonska    Pestisida  Tenaga_Kerja
# count      60.000000    60.000000     60.000000
# mean       21.333333  1365.000000     27.966667
# std        14.931104   819.637167     11.286660
# min         8.000000   400.000000     12.000000
# ...

# %% [markdown]
# # Visualisasi Data

# %%
plt.figure(figsize=(10,8))
sns.heatmap(df.corr(),annot=True)
# Out:
# <Axes: >

# %% [markdown]
# # distribusi Jumlah Pohon

# %%
plt.figure(figsize=(15,5))
sns.distplot(df['Jumlah_Pohon'])
# Out:
# C:\Users\Nurthariqa\AppData\Local\Temp\ipykernel_2880\886631216.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['Jumlah_Pohon'])
# <Axes: xlabel='Jumlah_Pohon', ylabel='Density'>

# %% [markdown]
# # distribusi Jumlah Produksi

# %%
plt.figure(figsize=(15,5))
sns.distplot(df['Jumlah_Produksi'])
# Out:
# C:\Users\Nurthariqa\AppData\Local\Temp\ipykernel_2880\3225709350.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['Jumlah_Produksi'])
# <Axes: xlabel='Jumlah_Produksi', ylabel='Density'>

# %% [markdown]
# # seleksi fitur

# %%
features = ['Luas_Lahan','Jumlah_Pohon','Pupuk_Kandang','Pupuk_Phonska','Pestisida','Tenaga_Kerja']
x = df[features]
y = df['Jumlah_Produksi']
x.shape, y.shape
# Out:
# ((60, 6), (60,))

# %% [markdown]
# # split data training dan data testing

# %%
from sklearn.model_selection import train_test_split
x_train, X_test, y_train, y_test = train_test_split(x,y,random_state=70)
y_test.shape
# Out:
# (15,)

# %% [markdown]
# # membuat model regresi linier

# %%
from sklearn.linear_model import LinearRegression
lr = LinearRegression()
lr.fit(x_train,y_train)
pred = lr.predict(X_test)

# %%
score = lr.score(X_test, y_test)
print('akurasi model regresi linier = ', score)
# Out:
# akurasi model regresi linier =  0.9865125122084153

# %% [markdown]
# # membuat inputan model regresi linier

# %%
input_data = np.array([[900,20,50,10,600,27]])

#calories = 830
prediction = lr.predict(input_data) 
print('Estimasi Jumlah Produksi :', prediction)
# Out:
# Estimasi Jumlah Kalori : [167.41265603]
# c:\Users\Nurthariqa\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\base.py:439: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(

# %% [markdown]
# # save model

# %%
import pickle

filename = 'estimasi_jumlahproduksi.sav'
pickle.dump(lr,open(filename,'wb'))
